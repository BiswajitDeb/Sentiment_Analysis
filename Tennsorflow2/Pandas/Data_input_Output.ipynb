# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Amazon Review.csv')

# %%
df
# Out:
#                  id          profileName  \
# 0     RWS8UP8OIV143             chetndas
# 1     RPVI7IROPB5XC        Santosh Kumar
# 2    R2YTS6C1C1LKTQ              Soundar
# 3    R3FGBKB32XK7TP  Vagmi Saras Pvt Ltd
# 4    R2E9BEOHS5UC4L                 Ojas
# ..              ...                  ...
# 744  R30YV3R93HCU45           Shourya M.
# 745  R20O1FZVCYQFYO      Tejasvi Bhosale
# 746  R2FQSYQS2ZXEOD     Gadde Ajay Kumar
# 747  R1H8L9FODM1STX        Kartik madnur
# 748  R17Q79ARAGNOVL                Harsh
#
#                                                   text  \
# 0    Got it for 80K in last sale after all discount...
# 1                    Giving 5 star for its performance
# 2       Value for money ! Very Good performing machine
# 3    MacBook Air is one of favourite from 2017 clas...
# 4           Best in class go for it ,works like charm.
# ..                                                 ...
# 744  Amazing device with lighting fast chip inside ...
# ...
